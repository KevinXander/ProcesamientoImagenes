# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinXander/ProcesamientoImagenes/blob/master/Clase5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/drive/My Drive/Procesamiento Imagenes/icono.png')
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
img2 = cv2.imread('/content/drive/My Drive/Procesamiento Imagenes/icono2.jpg')
plt.imshow(img2)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# # **Metodos necesarios**

# %%
#Metodo para mostrar dos imagenes
def display_two(a, b, title1 = "", title2= ""):
  plt.figure(figsize=(14,14))
  plt.subplot(121), plt.imshow(a), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(122), plt.imshow(b), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.show()

#Metodo para pasar una imagen BGR a RGB
def readRGB(imagenBGR):
  img_RGB=cv2.cvtColor(imagenBGR, cv2.COLOR_BGR2RGB)
  plt.imshow(img_RGB)
  plt.xticks([])
  plt.yticks([])
  plt.show()
  return img_RGB

# %% [markdown]
# # **Interpolación Nearest Neighbour**

# %%
imgA = readRGB(img)
imgB = readRGB(img2)
near_imgA = cv2.resize(imgA, None, fx=5, fy=5, interpolation = cv2.INTER_NEAREST)
near_imgB = cv2.resize(imgB, None, fx=5, fy=5, interpolation = cv2.INTER_NEAREST)
display_two(near_imgA, near_imgB, 'Logo', 'Manzana')

# %% [markdown]
# # **Interpolacion Bilinear**

# %%
imgA = readRGB(img)
imgB = readRGB(img2)
bili_imgA = cv2.resize(imgA, None, fx=5, fy=5, interpolation = cv2.INTER_LINEAR)
bili_imgB = cv2.resize(imgB, None, fx=5, fy=5, interpolation = cv2.INTER_LINEAR)
display_two(bili_imgA, bili_imgB, 'Logo', 'Manzana')

# %% [markdown]
# # **Interpolación Bicubica**

# %%
imgA = readRGB(img)
imgB = readRGB(img2)
bicu_imgA = cv2.resize(imgA, None, fx=5, fy=5, interpolation = cv2.INTER_CUBIC)
bicu_imgB = cv2.resize(imgB, None, fx=5, fy=5, interpolation = cv2.INTER_CUBIC)
display_two(bicu_imgA, bicu_imgB, 'Logo', 'Manzana')

# %% [markdown]
# # **Mostrando todas juntas**

# %%
def display_three(a, b,c, title1 = "", title2= "", title3=""):
  plt.figure(figsize=(14,14))
  plt.subplot(131), plt.imshow(a), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(132), plt.imshow(b), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.subplot(133), plt.imshow(c), plt.title(title3)
  plt.xticks([]), plt.yticks([])
  plt.show()

display_three(near_imgA, bili_imgA, bicu_imgA, "Nearest", "Bilineal", "Bicubica")

# %%
display_three(near_imgB, bili_imgB, bicu_imgB, "Nearest", "Bilineal", "Bicubica")

# %% [markdown]
# # **Otra forma y otras formas de interpolar**

# %%
methods = [None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 
             'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos']

#grid = np.random.rand(4,4)
grid = imgA

fig, axes = plt.subplots(3, 6, figsize = (12,6), subplot_kw={'xticks':[], 'yticks':[]})

fig.subplots_adjust(hspace = 0.3, wspace=0.05)

for ax, interp_method in zip(axes.flat, methods):
  ax.imshow(grid, interpolation = interp_method)
  ax.set_title(interp_method)

plt.show()
